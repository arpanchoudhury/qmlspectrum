# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_bar_compare(lambda_min, Int1, Int2, dlambda, label, filename):
    label1=label[0]
    label2=label[1]
    plt.bar(lambda_min, Int1, width = dlambda, label=label1,  color='red', alpha=0.2, align='edge', edgecolor='red')
    plt.bar(lambda_min, Int2, width = dlambda, label=label2,  alpha=1.0, align='edge', fill=False, edgecolor='red')
    plt.legend()
    plt.xlabel('Wavelength (nm)', fontsize = 15)
    plt.ylabel('Oscillator strength (au)', fontsize = 15)
    plt.savefig(filename,bbox_inches='tight')
    plt.show()
    #plt.clf()
    return 1

# %%
f=open('Int_25.0spec_den_DKI.dat', 'r')
lambda_min=[]
dlambda=[]
Int1=[]
Int2=[]
for line in f:
    string=line.split()
    lambda_min.append(float(string[0]))
    dlambda.append(float(string[1]))
    Int1.append(float(string[2]))
    Int2.append(float(string[3]))
f.close()
lambda_min=np.array(lambda_min)
dlambda=np.array(dlambda)
Int1=np.array(Int1)
Int2=np.array(Int2)
print('bin-widths:',dlambda)
print('Minimum bin-width is',np.min(dlambda))
print('Maximum bin-width is',np.max(dlambda))
dI=Int1/np.sum(Int1) - Int2/np.sum(Int2)
print(dI)
error=np.sum(np.abs(dI))
phi=100*(1-error)
print('Confidence score:',phi)
label=['ML (score=99.0)','TDDFT']
plot_bar_compare(lambda_min, Int1, Int2, dlambda, label, 'compare_ML_TDDFT_25.0_spec_den.png')
# Out:
# bin-widths: [ 48.73857651 548.71668185]
# Minimum bin-width is 48.73857651041601
# Maximum bin-width is 548.7166818471251
# [-0.00501188  0.00501188]
# Confidence score: 98.99762488152577
# 1

# %%
f=open('Int_10.0spec_den_DKI.dat', 'r')
lambda_min=[]
dlambda=[]
Int1=[]
Int2=[]
for line in f:
    string=line.split()
    lambda_min.append(float(string[0]))
    dlambda.append(float(string[1]))
    Int1.append(float(string[2]))
    Int2.append(float(string[3]))
f.close()
lambda_min=np.array(lambda_min)
dlambda=np.array(dlambda)
Int1=np.array(Int1)
Int2=np.array(Int2)
print('bin-widths:',dlambda)
print('Minimum bin-width is',np.min(dlambda))
print('Maximum bin-width is',np.max(dlambda))
dI=Int1/np.sum(Int1) - Int2/np.sum(Int2)
print(dI)
error=np.sum(np.abs(dI))
phi=100*(1-error)
print('Confidence score:',phi)
label=['ML (score=87.4)','TDDFT']
plot_bar_compare(lambda_min, Int1, Int2, dlambda, label, 'compare_ML_TDDFT_10.0_spec_den.png')
# Out:
# bin-widths: [ 17.75016005  20.19085487  23.22235964  29.09543741 507.19644639]
# Minimum bin-width is 17.750160047376397
# Maximum bin-width is 507.196446385392
# [-0.00789478 -0.03197721  0.06184615 -0.02329985  0.0013257 ]
# Confidence score: 87.3656318497035
# 1

# %%
f=open('Int_5.0spec_den_DKI.dat', 'r')
lambda_min=[]
dlambda=[]
Int1=[]
Int2=[]
for line in f:
    string=line.split()
    lambda_min.append(float(string[0]))
    dlambda.append(float(string[1]))
    Int1.append(float(string[2]))
    Int2.append(float(string[3]))
f.close()
lambda_min=np.array(lambda_min)
dlambda=np.array(dlambda)
Int1=np.array(Int1)
Int2=np.array(Int2)
print('bin-widths:',dlambda)
print('Minimum bin-width is',np.min(dlambda))
print('Maximum bin-width is',np.max(dlambda))
dI=Int1/np.sum(Int1) - Int2/np.sum(Int2)
print(dI)
error=np.sum(np.abs(dI))
phi=100*(1-error)
print('Confidence score:',phi)
label=['ML (score=67.7)','TDDFT']
plot_bar_compare(lambda_min, Int1, Int2, dlambda, label, 'compare_ML_TDDFT_5.0_spec_den.png')
# Out:
# bin-widths: [ 10.55903939   7.19112066  10.30302667   9.8878282   10.79756159
#   12.42479805  14.25289214  14.84254528  50.81802001 456.37842638]
# Minimum bin-width is 7.191120659985927
# Maximum bin-width is 456.3784263755646
# [-0.04068834  0.03279355 -0.00794817 -0.02402904  0.03486011  0.02698603
#  -0.0687215   0.04542165 -0.01987402  0.02119971]
# Confidence score: 67.74778829593298
# 1

# %%
f=open('Int_2.0spec_den_DKI.dat', 'r')
lambda_min=[]
dlambda=[]
Int1=[]
Int2=[]
for line in f:
    string=line.split()
    lambda_min.append(float(string[0]))
    dlambda.append(float(string[1]))
    Int1.append(float(string[2]))
    Int2.append(float(string[3]))
f.close()
lambda_min=np.array(lambda_min)
dlambda=np.array(dlambda)
Int1=np.array(Int1)
Int2=np.array(Int2)
print('bin-widths:',dlambda)
print('Minimum bin-width is',np.min(dlambda))
print('Maximum bin-width is',np.max(dlambda))
dI=Int1/np.sum(Int1) - Int2/np.sum(Int2)
print(dI)
error=np.sum(np.abs(dI))
phi=100*(1-error)
print('Confidence score:',phi)
label=['ML (score=30.5)','TDDFT']
plot_bar_compare(lambda_min, Int1, Int2, dlambda, label, 'compare_ML_TDDFT_2.0_spec_den.png')
# Out:
# bin-widths: [  6.36514231   2.90694333   2.6817886    2.74960411   3.0466817
#    3.98432059   4.2259604    3.82130686   4.02709465   4.13217237
#    4.36579833   4.32409416   5.07349562   4.72254914   4.7364224
#    5.33752739   5.95028118   5.32059307   5.47293308   7.01410269
#   10.17822196  17.32518106  77.06585179 130.66147454 271.96571704]
# Minimum bin-width is 2.6817886046847264
# Maximum bin-width is 271.96571704045834
# [-0.02111895 -0.01948506 -0.01869451  0.038175    0.01322875 -0.01249347
#  -0.0061744  -0.05216413 -0.06158265  0.10043745  0.02650864  0.01909234
#  -0.04259085 -0.01684765  0.07568366  0.01081478 -0.0194878  -0.00756896
#   0.01403629 -0.02109417 -0.02515944  0.0289018  -0.02311944  0.00444745
#   0.01625532]
# Confidence score: 30.483703460958502
# 1
